# %% [markdown]
# # Tugas Besar 1 IF4071 Pembelajaran Mesin
#
# 13515025 Kukuh Basuki Rahmat
# 13515037 Muhammad Irfan Maulana
# 13515071 Daniel Pintara
#
# ## Inisialisasi Dataset

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(100, centers=3, random_state=42)

from matplotlib.pyplot import scatter

# %matplotlib inline
scatter(X[:, 0], X[:, 1], c=y, cmap='rainbow')

# %% [markdown]
# ## Uji Coba
#
# ### DBSCAN

# %%
from ml_course import DBSCAN

model = DBSCAN()
y_pred = model.fit_predict(X)

from matplotlib.pyplot import scatter

# %matplotlib inline
scatter(X[:, 0], X[:, 1], c=y_pred, cmap='rainbow')
